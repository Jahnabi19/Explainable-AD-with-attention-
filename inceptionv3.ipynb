# %%
# Import the necessary packages

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import os
import matplotlib.pyplot as plt
import PIL
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from IPython.display import display
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
from tensorflow.keras import models
from tensorflow.keras.preprocessing import image
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping
import keras
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, cohen_kappa_score, precision_score, recall_score, f1_score
from sklearn.model_selection import KFold
import seaborn as sns

# %%
train_datagen = ImageDataGenerator(rescale=1./255, 
                                   shear_range=0.2, 
                                   zoom_range=0.2, 
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_set = train_datagen.flow_from_directory('/kaggle/input/best-alzheimer-mri-dataset-99-accuracy/Combined Dataset/train/', 
                                              target_size=(256, 256), 
                                              batch_size=32, 
                                              class_mode='categorical')
test_set = test_datagen.flow_from_directory('/kaggle/input/best-alzheimer-mri-dataset-99-accuracy/Combined Dataset/test/', 
                                            target_size=(256, 256), 
                                            batch_size=32, 
                                            class_mode='categorical',
                                            shuffle=False)
# Out:
# Found 10240 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
train_path='/kaggle/input/best-alzheimer-mri-dataset-99-accuracy/Combined Dataset/train/'
No_images_per_class = []
Class_name = []
for i in os.listdir(train_path):
  train_class = os.listdir(os.path.join(train_path, i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in No Impairment = 2560
#
# Number of images in Very Mild Impairment = 2560
#
# Number of images in Moderate Impairment = 2560
#
# Number of images in Mild Impairment = 2560

# %%
test_path='/kaggle/input/best-alzheimer-mri-dataset-99-accuracy/Combined Dataset/test/'
No_images_per_class = []
Class_name = []
for i in os.listdir(test_path):
  train_class = os.listdir(os.path.join(test_path, i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in No Impairment = 640
#
# Number of images in Very Mild Impairment = 448
#
# Number of images in Moderate Impairment = 12
#
# Number of images in Mild Impairment = 179

# %%
from glob import glob
# useful for getting number of output classes
folders = glob('/kaggle/input/best-alzheimer-mri-dataset-99-accuracy/Combined Dataset/train/*')
print(len(folders))
# Out:
# 4

# %%
from keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, GlobalAveragePooling2D
img_width, img_height = 256,256

base_model = InceptionV3(weights='imagenet', 
                                include_top=False, 
                                input_shape=(img_width, img_height, 3))
# don't train existing weights
for layer in base_model.layers:
  layer.trainable = False

add_model = Sequential()
add_model.add(base_model)
add_model.add(GlobalAveragePooling2D())
add_model.add(Dropout(0.3))
add_model.add(Dense(len(folders), activation='softmax'))

model = add_model
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
from keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, GlobalAveragePooling2D
img_width, img_height = 256,256

base_model = InceptionV3(weights='imagenet', 
                                include_top=False, 
                                input_shape=(img_width, img_height, 3))
# don't train existing weights
for layer in base_model.layers:
  layer.trainable = False


# Add a global average pooling layer and a fully connected layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(len(folders), activation='softmax')(x)

# %%
# Create the transfer learning model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
lr = 0.001
model.compile(Adam(learning_rate=lr),loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_94 (Conv2D)             (None, 127, 127, 32  864         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 127, 127, 32  96         ['conv2d_94[0][0]']
#  ormalization)                  )
#
#  activation_94 (Activation)     (None, 127, 127, 32  0           ['batch_normalization_94[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 125, 125, 32  9216        ['activation_94[0][0]']
#                                 )
#
#  batch_normalization_95 (BatchN  (None, 125, 125, 32  96         ['conv2d_95[0][0]']
#  ormalization)                  )
#
#  activation_95 (Activation)     (None, 125, 125, 32  0           ['batch_normalization_95[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 125, 125, 64  18432       ['activation_95[0][0]']
#                                 )
#
#  batch_normalization_96 (BatchN  (None, 125, 125, 64  192        ['conv2d_96[0][0]']
#  ormalization)                  )
#
#  activation_96 (Activation)     (None, 125, 125, 64  0           ['batch_normalization_96[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 62, 62, 64)  0           ['activation_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 62, 62, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 62, 62, 80)  240         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 62, 62, 80)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 60, 60, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 60, 60, 192)  576        ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 60, 60, 192)  0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 29, 29, 192)  0          ['activation_98[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 29, 29, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (Batch  (None, 29, 29, 64)  192         ['conv2d_102[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 29, 29, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 29, 29, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_100 (Batch  (None, 29, 29, 48)  144         ['conv2d_100[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 29, 29, 96)  288         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 29, 29, 48)   0           ['batch_normalization_100[0][0]']
#
#  activation_103 (Activation)    (None, 29, 29, 96)   0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 29, 29, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_99 (Conv2D)             (None, 29, 29, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 29, 29, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 29, 29, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 29, 29, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 29, 29, 64)  192         ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None, 29, 29, 64)  192         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 29, 29, 96)  288         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 29, 29, 32)  96          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 29, 29, 64)   0           ['batch_normalization_99[0][0]']
#
#  activation_101 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_101[0][0]']
#
#  activation_104 (Activation)    (None, 29, 29, 96)   0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (None, 29, 29, 32)   0           ['batch_normalization_105[0][0]']
#
#  mixed0 (Concatenate)           (None, 29, 29, 256)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 29, 29, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_109 (Batch  (None, 29, 29, 64)  192         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 29, 29, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 29, 29, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_107 (Batch  (None, 29, 29, 48)  144         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 29, 29, 96)  288         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 29, 29, 48)   0           ['batch_normalization_107[0][0]']
#
#  activation_110 (Activation)    (None, 29, 29, 96)   0           ['batch_normalization_110[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 29, 29, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_106 (Conv2D)            (None, 29, 29, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 29, 29, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 29, 29, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 29, 29, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (Batch  (None, 29, 29, 64)  192         ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 29, 29, 64)  192         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 29, 29, 96)  288         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 29, 29, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_106[0][0]']
#
#  activation_108 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_108[0][0]']
#
#  activation_111 (Activation)    (None, 29, 29, 96)   0           ['batch_normalization_111[0][0]']
#
#  activation_112 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_112[0][0]']
#
#  mixed1 (Concatenate)           (None, 29, 29, 288)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 29, 29, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_116 (Batch  (None, 29, 29, 64)  192         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_116[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 29, 29, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 29, 29, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_114 (Batch  (None, 29, 29, 48)  144         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 29, 29, 96)  288         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 29, 29, 48)   0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (None, 29, 29, 96)   0           ['batch_normalization_117[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 29, 29, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_113 (Conv2D)            (None, 29, 29, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 29, 29, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 29, 29, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 29, 29, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (Batch  (None, 29, 29, 64)  192         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 29, 29, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 29, 29, 96)  288         ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 29, 29, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_113[0][0]']
#
#  activation_115 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_115[0][0]']
#
#  activation_118 (Activation)    (None, 29, 29, 96)   0           ['batch_normalization_118[0][0]']
#
#  activation_119 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_119[0][0]']
#
#  mixed2 (Concatenate)           (None, 29, 29, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 29, 29, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_121 (Batch  (None, 29, 29, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 29, 29, 64)   0           ['batch_normalization_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 29, 29, 96)   55296       ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 29, 29, 96)  288         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 29, 29, 96)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 14, 14, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 14, 14, 96)   82944       ['activation_122[0][0]']
#
#  batch_normalization_120 (Batch  (None, 14, 14, 384)  1152       ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 14, 14, 96)  288         ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 14, 14, 384)  0           ['batch_normalization_120[0][0]']
#
#  activation_123 (Activation)    (None, 14, 14, 96)   0           ['batch_normalization_123[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 14, 14, 768)  0           ['activation_120[0][0]',
#                                                                   'activation_123[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 14, 14, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_128 (Batch  (None, 14, 14, 128)  384        ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 14, 14, 128)  114688      ['activation_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 14, 14, 128)  384        ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_129[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 14, 14, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 14, 14, 128)  114688      ['activation_129[0][0]']
#
#  batch_normalization_125 (Batch  (None, 14, 14, 128)  384        ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 14, 14, 128)  384        ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_125[0][0]']
#
#  activation_130 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_130[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 14, 14, 128)  114688      ['activation_125[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 14, 14, 128)  114688      ['activation_130[0][0]']
#
#  batch_normalization_126 (Batch  (None, 14, 14, 128)  384        ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 14, 14, 128)  384        ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_126[0][0]']
#
#  activation_131 (Activation)    (None, 14, 14, 128)  0           ['batch_normalization_131[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 14, 14, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_124 (Conv2D)            (None, 14, 14, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 14, 14, 192)  172032      ['activation_126[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 14, 14, 192)  172032      ['activation_131[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 14, 14, 192)  147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (Batch  (None, 14, 14, 192)  576        ['conv2d_124[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 14, 14, 192)  576        ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 14, 14, 192)  576        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 14, 14, 192)  576        ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_124[0][0]']
#
#  activation_127 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_127[0][0]']
#
#  activation_132 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_132[0][0]']
#
#  activation_133 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_133[0][0]']
#
#  mixed4 (Concatenate)           (None, 14, 14, 768)  0           ['activation_124[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 14, 14, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_138 (Batch  (None, 14, 14, 160)  480        ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 14, 14, 160)  480        ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 14, 14, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_139[0][0]']
#
#  batch_normalization_135 (Batch  (None, 14, 14, 160)  480        ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 14, 14, 160)  480        ['conv2d_140[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_135[0][0]']
#
#  activation_140 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_135[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_140[0][0]']
#
#  batch_normalization_136 (Batch  (None, 14, 14, 160)  480        ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 14, 14, 160)  480        ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_136[0][0]']
#
#  activation_141 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 14, 14, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_134 (Conv2D)            (None, 14, 14, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 14, 14, 192)  215040      ['activation_136[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 14, 14, 192)  215040      ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 14, 14, 192)  147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (Batch  (None, 14, 14, 192)  576        ['conv2d_134[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 14, 14, 192)  576        ['conv2d_137[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 14, 14, 192)  576        ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 14, 14, 192)  576        ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_134[0][0]']
#
#  activation_137 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_137[0][0]']
#
#  activation_142 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_143[0][0]']
#
#  mixed5 (Concatenate)           (None, 14, 14, 768)  0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 14, 14, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_148 (Batch  (None, 14, 14, 160)  480        ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 14, 14, 160)  480        ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 14, 14, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_149[0][0]']
#
#  batch_normalization_145 (Batch  (None, 14, 14, 160)  480        ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 14, 14, 160)  480        ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_145[0][0]']
#
#  activation_150 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_145[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 14, 14, 160)  179200      ['activation_150[0][0]']
#
#  batch_normalization_146 (Batch  (None, 14, 14, 160)  480        ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 14, 14, 160)  480        ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_146[0][0]']
#
#  activation_151 (Activation)    (None, 14, 14, 160)  0           ['batch_normalization_151[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 14, 14, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_144 (Conv2D)            (None, 14, 14, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 14, 14, 192)  215040      ['activation_146[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 14, 14, 192)  215040      ['activation_151[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 14, 14, 192)  147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_144 (Batch  (None, 14, 14, 192)  576        ['conv2d_144[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 14, 14, 192)  576        ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 14, 14, 192)  576        ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 14, 14, 192)  576        ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_144[0][0]']
#
#  activation_147 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_147[0][0]']
#
#  activation_152 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_152[0][0]']
#
#  activation_153 (Activation)    (None, 14, 14, 192)  0           ['batch_normalization_153[0][0]']
# ...
#
#  activation_174 (Activation)    (None, 6, 6, 448)    0           ['batch_normalization_174[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 6, 6, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 6, 6, 384)    1548288     ['activation_174[0][0]']
#
#  batch_normalization_171 (Batch  (None, 6, 6, 384)   1152        ['conv2d_171[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 6, 6, 384)   1152        ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_171[0][0]']
#
#  activation_175 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_175[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_175[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 6, 6, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_170 (Conv2D)            (None, 6, 6, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_172 (Batch  (None, 6, 6, 384)   1152        ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 6, 6, 384)   1152        ['conv2d_173[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (None, 6, 6, 384)   1152        ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 6, 6, 384)   1152        ['conv2d_177[0][0]']
#  Normalization)
#
#  conv2d_178 (Conv2D)            (None, 6, 6, 192)    245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (None, 6, 6, 320)   960         ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_172[0][0]']
#
#  activation_173 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_173[0][0]']
#
#  activation_176 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_176[0][0]']
#
#  activation_177 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_177[0][0]']
#
#  batch_normalization_178 (Batch  (None, 6, 6, 192)   576         ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 6, 6, 320)    0           ['batch_normalization_170[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 6, 6, 768)    0           ['activation_172[0][0]',
#                                                                   'activation_173[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 6, 6, 768)    0           ['activation_176[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_178[0][0]']
#
#  mixed9 (Concatenate)           (None, 6, 6, 2048)   0           ['activation_170[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_178[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 6, 6, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_183 (Batch  (None, 6, 6, 448)   1344        ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 6, 6, 448)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 6, 6, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 6, 6, 384)    1548288     ['activation_183[0][0]']
#
#  batch_normalization_180 (Batch  (None, 6, 6, 384)   1152        ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 6, 6, 384)   1152        ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_180[0][0]']
#
#  activation_184 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_184[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_184[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 6, 6, 384)    442368      ['activation_184[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 6, 6, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_179 (Conv2D)            (None, 6, 6, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_181 (Batch  (None, 6, 6, 384)   1152        ['conv2d_181[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 6, 6, 384)   1152        ['conv2d_182[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 6, 6, 384)   1152        ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 6, 6, 384)   1152        ['conv2d_186[0][0]']
#  Normalization)
#
#  conv2d_187 (Conv2D)            (None, 6, 6, 192)    393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (Batch  (None, 6, 6, 320)   960         ['conv2d_179[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_181[0][0]']
#
#  activation_182 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_182[0][0]']
#
#  activation_185 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_185[0][0]']
#
#  activation_186 (Activation)    (None, 6, 6, 384)    0           ['batch_normalization_186[0][0]']
#
#  batch_normalization_187 (Batch  (None, 6, 6, 192)   576         ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 6, 6, 320)    0           ['batch_normalization_179[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 6, 6, 768)    0           ['activation_181[0][0]',
#                                                                   'activation_182[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 6, 6, 768)    0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_187[0][0]']
#
#  mixed10 (Concatenate)          (None, 6, 6, 2048)   0           ['activation_179[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_187[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dropout_1 (Dropout)            (None, 2048)         0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_1 (Dense)                (None, 4)            8196        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 21,810,980
# Trainable params: 8,196
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
file_path="weights.best.hdf5"

checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
history = model.fit(train_set,
                    steps_per_epoch=train_set.samples//32,
                    epochs=100,
                    validation_data=test_set,
                    validation_steps=test_set.samples//32,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 320/320 [==============================] - ETA: 0s - loss: 0.9663 - accuracy: 0.5784
# Epoch 1: val_loss improved from inf to 0.96423, saving model to weights.best.hdf5
# 320/320 [==============================] - 233s 685ms/step - loss: 0.9663 - accuracy: 0.5784 - val_loss: 0.9642 - val_accuracy: 0.5481
# Epoch 2/100
# 320/320 [==============================] - ETA: 0s - loss: 0.7769 - accuracy: 0.6659
# Epoch 2: val_loss improved from 0.96423 to 0.90654, saving model to weights.best.hdf5
# 320/320 [==============================] - 152s 474ms/step - loss: 0.7769 - accuracy: 0.6659 - val_loss: 0.9065 - val_accuracy: 0.5649
# Epoch 3/100
# 320/320 [==============================] - ETA: 0s - loss: 0.7241 - accuracy: 0.6880
# Epoch 3: val_loss did not improve from 0.90654
# 320/320 [==============================] - 152s 475ms/step - loss: 0.7241 - accuracy: 0.6880 - val_loss: 0.9415 - val_accuracy: 0.5569
# Epoch 4/100
# 320/320 [==============================] - ETA: 0s - loss: 0.7061 - accuracy: 0.6915
# Epoch 4: val_loss improved from 0.90654 to 0.88989, saving model to weights.best.hdf5
# 320/320 [==============================] - 153s 477ms/step - loss: 0.7061 - accuracy: 0.6915 - val_loss: 0.8899 - val_accuracy: 0.5585
# Epoch 5/100
# 320/320 [==============================] - ETA: 0s - loss: 0.7008 - accuracy: 0.6916
# Epoch 5: val_loss did not improve from 0.88989
# 320/320 [==============================] - 153s 476ms/step - loss: 0.7008 - accuracy: 0.6916 - val_loss: 1.0966 - val_accuracy: 0.4688
# Epoch 6/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.7011
# Epoch 6: val_loss improved from 0.88989 to 0.87321, saving model to weights.best.hdf5
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6965 - accuracy: 0.7011 - val_loss: 0.8732 - val_accuracy: 0.5737
# Epoch 7/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6694 - accuracy: 0.7111
# Epoch 7: val_loss did not improve from 0.87321
# 320/320 [==============================] - 154s 480ms/step - loss: 0.6694 - accuracy: 0.7111 - val_loss: 0.9091 - val_accuracy: 0.5665
# Epoch 8/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.7157
# Epoch 8: val_loss did not improve from 0.87321
# 320/320 [==============================] - 152s 473ms/step - loss: 0.6636 - accuracy: 0.7157 - val_loss: 0.8811 - val_accuracy: 0.5881
# Epoch 9/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.7122
# Epoch 9: val_loss improved from 0.87321 to 0.85882, saving model to weights.best.hdf5
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6701 - accuracy: 0.7122 - val_loss: 0.8588 - val_accuracy: 0.5954
# Epoch 10/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6480 - accuracy: 0.7197
# Epoch 10: val_loss did not improve from 0.85882
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6480 - accuracy: 0.7197 - val_loss: 0.9140 - val_accuracy: 0.5593
# Epoch 11/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6492 - accuracy: 0.7148
# Epoch 11: val_loss did not improve from 0.85882
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6492 - accuracy: 0.7148 - val_loss: 0.9017 - val_accuracy: 0.5785
# Epoch 12/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6526 - accuracy: 0.7143
# Epoch 12: val_loss did not improve from 0.85882
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6526 - accuracy: 0.7143 - val_loss: 0.8907 - val_accuracy: 0.5769
# Epoch 13/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6546 - accuracy: 0.7163
# Epoch 13: val_loss did not improve from 0.85882
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6546 - accuracy: 0.7163 - val_loss: 0.9043 - val_accuracy: 0.5649
# Epoch 14/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6442 - accuracy: 0.7206
# Epoch 14: val_loss did not improve from 0.85882
# 320/320 [==============================] - 153s 479ms/step - loss: 0.6442 - accuracy: 0.7206 - val_loss: 0.9019 - val_accuracy: 0.5705
# Epoch 15/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6362 - accuracy: 0.7221
# Epoch 15: val_loss did not improve from 0.85882
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6362 - accuracy: 0.7221 - val_loss: 0.9152 - val_accuracy: 0.5745
# Epoch 16/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6373 - accuracy: 0.7212
# Epoch 16: val_loss did not improve from 0.85882
# 320/320 [==============================] - 154s 480ms/step - loss: 0.6373 - accuracy: 0.7212 - val_loss: 0.8723 - val_accuracy: 0.5641
# Epoch 17/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6540 - accuracy: 0.7160
# Epoch 17: val_loss did not improve from 0.85882
# 320/320 [==============================] - 156s 487ms/step - loss: 0.6540 - accuracy: 0.7160 - val_loss: 0.8598 - val_accuracy: 0.6010
# Epoch 18/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6431 - accuracy: 0.7205
# Epoch 18: val_loss improved from 0.85882 to 0.85607, saving model to weights.best.hdf5
# 320/320 [==============================] - 152s 476ms/step - loss: 0.6431 - accuracy: 0.7205 - val_loss: 0.8561 - val_accuracy: 0.5745
# Epoch 19/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.7179
# Epoch 19: val_loss improved from 0.85607 to 0.85221, saving model to weights.best.hdf5
# 320/320 [==============================] - 154s 480ms/step - loss: 0.6440 - accuracy: 0.7179 - val_loss: 0.8522 - val_accuracy: 0.5785
# Epoch 20/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6414 - accuracy: 0.7231
# Epoch 20: val_loss did not improve from 0.85221
# 320/320 [==============================] - 150s 469ms/step - loss: 0.6414 - accuracy: 0.7231 - val_loss: 0.9488 - val_accuracy: 0.5537
# Epoch 21/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.7260
# Epoch 21: val_loss improved from 0.85221 to 0.85154, saving model to weights.best.hdf5
# 320/320 [==============================] - 152s 476ms/step - loss: 0.6334 - accuracy: 0.7260 - val_loss: 0.8515 - val_accuracy: 0.5962
# Epoch 22/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6435 - accuracy: 0.7249
# Epoch 22: val_loss did not improve from 0.85154
# 320/320 [==============================] - 154s 481ms/step - loss: 0.6435 - accuracy: 0.7249 - val_loss: 0.8692 - val_accuracy: 0.5769
# Epoch 23/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6267 - accuracy: 0.7254
# Epoch 23: val_loss did not improve from 0.85154
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6267 - accuracy: 0.7254 - val_loss: 0.8596 - val_accuracy: 0.5986
# Epoch 24/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6410 - accuracy: 0.7210
# Epoch 24: val_loss improved from 0.85154 to 0.84257, saving model to weights.best.hdf5
# 320/320 [==============================] - 153s 479ms/step - loss: 0.6410 - accuracy: 0.7210 - val_loss: 0.8426 - val_accuracy: 0.5929
# Epoch 25/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.7290
# Epoch 25: val_loss improved from 0.84257 to 0.84032, saving model to weights.best.hdf5
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6339 - accuracy: 0.7290 - val_loss: 0.8403 - val_accuracy: 0.6034
# Epoch 26/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6346 - accuracy: 0.7229
# Epoch 26: val_loss did not improve from 0.84032
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6346 - accuracy: 0.7229 - val_loss: 0.9054 - val_accuracy: 0.5785
# Epoch 27/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6285 - accuracy: 0.7271
# Epoch 27: val_loss improved from 0.84032 to 0.83725, saving model to weights.best.hdf5
# 320/320 [==============================] - 155s 486ms/step - loss: 0.6285 - accuracy: 0.7271 - val_loss: 0.8373 - val_accuracy: 0.5905
# Epoch 28/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6352 - accuracy: 0.7261
# Epoch 28: val_loss did not improve from 0.83725
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6352 - accuracy: 0.7261 - val_loss: 0.8693 - val_accuracy: 0.5881
# Epoch 29/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.7248
# Epoch 29: val_loss did not improve from 0.83725
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6326 - accuracy: 0.7248 - val_loss: 0.8631 - val_accuracy: 0.6050
# Epoch 30/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.7333
# Epoch 30: val_loss did not improve from 0.83725
# 320/320 [==============================] - 153s 478ms/step - loss: 0.6262 - accuracy: 0.7333 - val_loss: 0.8839 - val_accuracy: 0.5729
# Epoch 31/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6321 - accuracy: 0.7281
# Epoch 31: val_loss did not improve from 0.83725
# 320/320 [==============================] - 153s 479ms/step - loss: 0.6321 - accuracy: 0.7281 - val_loss: 0.8483 - val_accuracy: 0.5865
# Epoch 32/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6344 - accuracy: 0.7294
# Epoch 32: val_loss did not improve from 0.83725
# 320/320 [==============================] - 153s 479ms/step - loss: 0.6344 - accuracy: 0.7294 - val_loss: 0.8447 - val_accuracy: 0.5954
# Epoch 33/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6277 - accuracy: 0.7250
# Epoch 33: val_loss did not improve from 0.83725
# 320/320 [==============================] - 151s 472ms/step - loss: 0.6277 - accuracy: 0.7250 - val_loss: 0.8679 - val_accuracy: 0.5946
# Epoch 34/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6281 - accuracy: 0.7292
# Epoch 34: val_loss did not improve from 0.83725
# 320/320 [==============================] - 151s 472ms/step - loss: 0.6281 - accuracy: 0.7292 - val_loss: 0.8978 - val_accuracy: 0.5801
# Epoch 35/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6254 - accuracy: 0.7299
# Epoch 35: val_loss did not improve from 0.83725
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6254 - accuracy: 0.7299 - val_loss: 0.8457 - val_accuracy: 0.6018
# Epoch 36/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6328 - accuracy: 0.7249
# Epoch 36: val_loss improved from 0.83725 to 0.83164, saving model to weights.best.hdf5
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6328 - accuracy: 0.7249 - val_loss: 0.8316 - val_accuracy: 0.5897
# Epoch 37/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.7256
# Epoch 37: val_loss did not improve from 0.83164
# 320/320 [==============================] - 151s 472ms/step - loss: 0.6304 - accuracy: 0.7256 - val_loss: 0.9178 - val_accuracy: 0.5657
# Epoch 38/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.7269
# Epoch 38: val_loss did not improve from 0.83164
# 320/320 [==============================] - 152s 476ms/step - loss: 0.6372 - accuracy: 0.7269 - val_loss: 0.8473 - val_accuracy: 0.5849
# Epoch 39/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6283 - accuracy: 0.7259
# Epoch 39: val_loss did not improve from 0.83164
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6283 - accuracy: 0.7259 - val_loss: 0.8613 - val_accuracy: 0.5777
# Epoch 40/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6275 - accuracy: 0.7270
# Epoch 40: val_loss did not improve from 0.83164
# 320/320 [==============================] - 150s 469ms/step - loss: 0.6275 - accuracy: 0.7270 - val_loss: 0.8324 - val_accuracy: 0.5873
# Epoch 41/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6316 - accuracy: 0.7257
# Epoch 41: val_loss did not improve from 0.83164
# 320/320 [==============================] - 153s 478ms/step - loss: 0.6316 - accuracy: 0.7257 - val_loss: 0.8522 - val_accuracy: 0.5897
# Epoch 42/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6174 - accuracy: 0.7308
# Epoch 42: val_loss did not improve from 0.83164
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6174 - accuracy: 0.7308 - val_loss: 0.8697 - val_accuracy: 0.5841
# Epoch 43/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6181 - accuracy: 0.7294
# Epoch 43: val_loss did not improve from 0.83164
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6181 - accuracy: 0.7294 - val_loss: 0.8453 - val_accuracy: 0.5921
# Epoch 44/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.7256
# Epoch 44: val_loss improved from 0.83164 to 0.82343, saving model to weights.best.hdf5
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6351 - accuracy: 0.7256 - val_loss: 0.8234 - val_accuracy: 0.5970
# Epoch 45/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.7300
# Epoch 45: val_loss did not improve from 0.82343
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6249 - accuracy: 0.7300 - val_loss: 0.8576 - val_accuracy: 0.5929
# Epoch 46/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.7291
# Epoch 46: val_loss did not improve from 0.82343
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6280 - accuracy: 0.7291 - val_loss: 0.8539 - val_accuracy: 0.5921
# Epoch 47/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.7314
# Epoch 47: val_loss did not improve from 0.82343
# 320/320 [==============================] - 151s 470ms/step - loss: 0.6203 - accuracy: 0.7314 - val_loss: 0.8329 - val_accuracy: 0.6002
# Epoch 48/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6472 - accuracy: 0.7193
# Epoch 48: val_loss did not improve from 0.82343
# 320/320 [==============================] - 153s 479ms/step - loss: 0.6472 - accuracy: 0.7193 - val_loss: 0.8426 - val_accuracy: 0.6002
# Epoch 49/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6191 - accuracy: 0.7288
# Epoch 49: val_loss did not improve from 0.82343
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6191 - accuracy: 0.7288 - val_loss: 0.8506 - val_accuracy: 0.5881
# Epoch 50/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6170 - accuracy: 0.7343
# Epoch 50: val_loss did not improve from 0.82343
# 320/320 [==============================] - 151s 472ms/step - loss: 0.6170 - accuracy: 0.7343 - val_loss: 0.8271 - val_accuracy: 0.5986
# Epoch 51/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.7232
# Epoch 51: val_loss did not improve from 0.82343
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6273 - accuracy: 0.7232 - val_loss: 0.8661 - val_accuracy: 0.5986
# Epoch 52/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6376 - accuracy: 0.7271
# Epoch 52: val_loss did not improve from 0.82343
# 320/320 [==============================] - 151s 473ms/step - loss: 0.6376 - accuracy: 0.7271 - val_loss: 0.8457 - val_accuracy: 0.5978
# Epoch 53/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6386 - accuracy: 0.7201
# Epoch 53: val_loss did not improve from 0.82343
# 320/320 [==============================] - 151s 473ms/step - loss: 0.6386 - accuracy: 0.7201 - val_loss: 0.8764 - val_accuracy: 0.5938
# Epoch 54/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6325 - accuracy: 0.7295
# Epoch 54: val_loss did not improve from 0.82343
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6325 - accuracy: 0.7295 - val_loss: 0.8483 - val_accuracy: 0.6026
# Epoch 55/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6215 - accuracy: 0.7288
# Epoch 55: val_loss did not improve from 0.82343
# 320/320 [==============================] - 152s 473ms/step - loss: 0.6215 - accuracy: 0.7288 - val_loss: 0.8513 - val_accuracy: 0.6058
# Epoch 56/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.7283
# Epoch 56: val_loss improved from 0.82343 to 0.82161, saving model to weights.best.hdf5
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6295 - accuracy: 0.7283 - val_loss: 0.8216 - val_accuracy: 0.6042
# Epoch 57/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6238 - accuracy: 0.7305
# Epoch 57: val_loss did not improve from 0.82161
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6238 - accuracy: 0.7305 - val_loss: 0.8802 - val_accuracy: 0.5921
# Epoch 58/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6293 - accuracy: 0.7239
# Epoch 58: val_loss did not improve from 0.82161
# 320/320 [==============================] - 150s 468ms/step - loss: 0.6293 - accuracy: 0.7239 - val_loss: 0.8384 - val_accuracy: 0.6066
# Epoch 59/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6362 - accuracy: 0.7224
# Epoch 59: val_loss did not improve from 0.82161
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6362 - accuracy: 0.7224 - val_loss: 0.8301 - val_accuracy: 0.5857
# Epoch 60/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6284 - accuracy: 0.7284
# Epoch 60: val_loss did not improve from 0.82161
# 320/320 [==============================] - 150s 468ms/step - loss: 0.6284 - accuracy: 0.7284 - val_loss: 0.9445 - val_accuracy: 0.5713
# Epoch 61/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6329 - accuracy: 0.7262
# Epoch 61: val_loss improved from 0.82161 to 0.81488, saving model to weights.best.hdf5
# 320/320 [==============================] - 151s 472ms/step - loss: 0.6329 - accuracy: 0.7262 - val_loss: 0.8149 - val_accuracy: 0.6074
# Epoch 62/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6219 - accuracy: 0.7334
# Epoch 62: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6219 - accuracy: 0.7334 - val_loss: 0.8451 - val_accuracy: 0.5938
# Epoch 63/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.7292
# Epoch 63: val_loss did not improve from 0.81488
# 320/320 [==============================] - 150s 470ms/step - loss: 0.6273 - accuracy: 0.7292 - val_loss: 0.8254 - val_accuracy: 0.5938
# Epoch 64/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6242 - accuracy: 0.7262
# Epoch 64: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6242 - accuracy: 0.7262 - val_loss: 0.8670 - val_accuracy: 0.5801
# Epoch 65/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.7305
# Epoch 65: val_loss did not improve from 0.81488
# 320/320 [==============================] - 150s 468ms/step - loss: 0.6177 - accuracy: 0.7305 - val_loss: 0.8365 - val_accuracy: 0.5978
# Epoch 66/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6192 - accuracy: 0.7335
# Epoch 66: val_loss did not improve from 0.81488
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6192 - accuracy: 0.7335 - val_loss: 0.8232 - val_accuracy: 0.6106
# Epoch 67/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6199 - accuracy: 0.7320
# Epoch 67: val_loss did not improve from 0.81488
# 320/320 [==============================] - 153s 479ms/step - loss: 0.6199 - accuracy: 0.7320 - val_loss: 0.8276 - val_accuracy: 0.6170
# Epoch 68/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6398 - accuracy: 0.7258
# Epoch 68: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6398 - accuracy: 0.7258 - val_loss: 0.8524 - val_accuracy: 0.5962
# Epoch 69/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.7228
# Epoch 69: val_loss did not improve from 0.81488
# 320/320 [==============================] - 151s 472ms/step - loss: 0.6334 - accuracy: 0.7228 - val_loss: 0.8350 - val_accuracy: 0.6058
# Epoch 70/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6212 - accuracy: 0.7367
# Epoch 70: val_loss did not improve from 0.81488
# 320/320 [==============================] - 151s 470ms/step - loss: 0.6212 - accuracy: 0.7367 - val_loss: 0.8396 - val_accuracy: 0.5905
# Epoch 71/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.7253
# Epoch 71: val_loss did not improve from 0.81488
# 320/320 [==============================] - 153s 479ms/step - loss: 0.6300 - accuracy: 0.7253 - val_loss: 0.8547 - val_accuracy: 0.5889
# Epoch 72/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6204 - accuracy: 0.7289
# Epoch 72: val_loss did not improve from 0.81488
# 320/320 [==============================] - 153s 478ms/step - loss: 0.6204 - accuracy: 0.7289 - val_loss: 0.8626 - val_accuracy: 0.5954
# Epoch 73/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6226 - accuracy: 0.7290
# Epoch 73: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6226 - accuracy: 0.7290 - val_loss: 0.8691 - val_accuracy: 0.5954
# Epoch 74/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.7265
# Epoch 74: val_loss did not improve from 0.81488
# 320/320 [==============================] - 153s 478ms/step - loss: 0.6248 - accuracy: 0.7265 - val_loss: 0.8474 - val_accuracy: 0.5954
# Epoch 75/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6417 - accuracy: 0.7231
# Epoch 75: val_loss did not improve from 0.81488
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6417 - accuracy: 0.7231 - val_loss: 0.8278 - val_accuracy: 0.5865
# Epoch 76/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6193 - accuracy: 0.7261
# Epoch 76: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6193 - accuracy: 0.7261 - val_loss: 0.8207 - val_accuracy: 0.6042
# Epoch 77/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6365 - accuracy: 0.7232
# Epoch 77: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6365 - accuracy: 0.7232 - val_loss: 0.9203 - val_accuracy: 0.5609
# Epoch 78/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6352 - accuracy: 0.7229
# Epoch 78: val_loss did not improve from 0.81488
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6352 - accuracy: 0.7229 - val_loss: 0.8302 - val_accuracy: 0.5929
# Epoch 79/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6143 - accuracy: 0.7346
# Epoch 79: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 476ms/step - loss: 0.6143 - accuracy: 0.7346 - val_loss: 0.9063 - val_accuracy: 0.5577
# Epoch 80/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.7292
# Epoch 80: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6214 - accuracy: 0.7292 - val_loss: 0.8497 - val_accuracy: 0.6042
# Epoch 81/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.7271
# Epoch 81: val_loss did not improve from 0.81488
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6237 - accuracy: 0.7271 - val_loss: 0.8273 - val_accuracy: 0.6050
# Epoch 82/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6229 - accuracy: 0.7280
# Epoch 82: val_loss improved from 0.81488 to 0.81319, saving model to weights.best.hdf5
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6229 - accuracy: 0.7280 - val_loss: 0.8132 - val_accuracy: 0.6026
# Epoch 83/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6178 - accuracy: 0.7283
# Epoch 83: val_loss did not improve from 0.81319
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6178 - accuracy: 0.7283 - val_loss: 0.8769 - val_accuracy: 0.5673
# Epoch 84/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6277 - accuracy: 0.7354
# Epoch 84: val_loss did not improve from 0.81319
# 320/320 [==============================] - 151s 473ms/step - loss: 0.6277 - accuracy: 0.7354 - val_loss: 0.8292 - val_accuracy: 0.6106
# Epoch 85/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.7269
# Epoch 85: val_loss did not improve from 0.81319
# 320/320 [==============================] - 151s 471ms/step - loss: 0.6304 - accuracy: 0.7269 - val_loss: 0.8743 - val_accuracy: 0.5785
# Epoch 86/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6209 - accuracy: 0.7334
# Epoch 86: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 473ms/step - loss: 0.6209 - accuracy: 0.7334 - val_loss: 0.8249 - val_accuracy: 0.6050
# Epoch 87/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6311 - accuracy: 0.7352
# Epoch 87: val_loss did not improve from 0.81319
# 320/320 [==============================] - 177s 553ms/step - loss: 0.6311 - accuracy: 0.7352 - val_loss: 0.8386 - val_accuracy: 0.5889
# Epoch 88/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6340 - accuracy: 0.7241
# Epoch 88: val_loss did not improve from 0.81319
# 320/320 [==============================] - 178s 555ms/step - loss: 0.6340 - accuracy: 0.7241 - val_loss: 0.8193 - val_accuracy: 0.5986
# Epoch 89/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.7268
# Epoch 89: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 473ms/step - loss: 0.6292 - accuracy: 0.7268 - val_loss: 0.8177 - val_accuracy: 0.6242
# Epoch 90/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6206 - accuracy: 0.7310
# Epoch 90: val_loss did not improve from 0.81319
# 320/320 [==============================] - 153s 478ms/step - loss: 0.6206 - accuracy: 0.7310 - val_loss: 0.8245 - val_accuracy: 0.6010
# Epoch 91/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.7283
# Epoch 91: val_loss did not improve from 0.81319
# 320/320 [==============================] - 153s 477ms/step - loss: 0.6262 - accuracy: 0.7283 - val_loss: 0.8240 - val_accuracy: 0.5986
# Epoch 92/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.7288
# Epoch 92: val_loss did not improve from 0.81319
# 320/320 [==============================] - 154s 480ms/step - loss: 0.6331 - accuracy: 0.7288 - val_loss: 0.8834 - val_accuracy: 0.5873
# Epoch 93/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6269 - accuracy: 0.7307
# Epoch 93: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6269 - accuracy: 0.7307 - val_loss: 0.8379 - val_accuracy: 0.5833
# Epoch 94/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6336 - accuracy: 0.7274
# Epoch 94: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6336 - accuracy: 0.7274 - val_loss: 0.8445 - val_accuracy: 0.6018
# Epoch 95/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6308 - accuracy: 0.7288
# Epoch 95: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 473ms/step - loss: 0.6308 - accuracy: 0.7288 - val_loss: 0.8914 - val_accuracy: 0.5625
# Epoch 96/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.7299
# Epoch 96: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 474ms/step - loss: 0.6214 - accuracy: 0.7299 - val_loss: 0.8439 - val_accuracy: 0.6018
# Epoch 97/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6220 - accuracy: 0.7254
# Epoch 97: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6220 - accuracy: 0.7254 - val_loss: 0.8218 - val_accuracy: 0.5962
# Epoch 98/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6337 - accuracy: 0.7206
# Epoch 98: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6337 - accuracy: 0.7206 - val_loss: 0.8388 - val_accuracy: 0.5978
# Epoch 99/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6178 - accuracy: 0.7297
# Epoch 99: val_loss did not improve from 0.81319
# 320/320 [==============================] - 152s 475ms/step - loss: 0.6178 - accuracy: 0.7297 - val_loss: 0.8954 - val_accuracy: 0.5729
# Epoch 100/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.7159
# Epoch 100: val_loss did not improve from 0.81319
# 320/320 [==============================] - 153s 478ms/step - loss: 0.6447 - accuracy: 0.7159 - val_loss: 0.8258 - val_accuracy: 0.6074

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
# Extracting the validation accuracy values and finding the epoch with the highest value
val_acc = history.history['val_accuracy']
best_epoch = val_acc.index(max(val_acc)) + 1  # Add 1 to convert index to epoch number

# Plotting the training history
epochs = range(1, len(val_acc) + 1)
plt.plot(epochs, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')

# Highlighting the epoch with the highest validation accuracy
plt.plot(best_epoch, val_acc[best_epoch - 1], marker='o', markersize=10, label=f'Best Epoch ({best_epoch}, {val_acc[best_epoch - 1]:.4f})', color='red')

# Adding plot labels and legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()

# %%
from tensorflow.keras.models import load_model

model.save('best_weights.h5')

# %%
# load model
model = load_model('/kaggle/working/best_weights.h5')

# %%
# Evaluate the performance of the model
evaluate = model.evaluate(test_set, steps = test_set.n // 32, verbose =1)

print('Accuracy Test : {}'.format(evaluate[1]))
# Out:
# 39/39 [==============================] - 5s 93ms/step - loss: 0.8258 - accuracy: 0.6074
# Accuracy Test : 0.6073718070983887

# %%
y_pred = model.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)

cm = confusion_matrix(test_set.classes, y_pred)
cr = classification_report(test_set.classes, y_pred, target_names=['Mild Impairment', 'Moderate Impairment', 'No Impairment', 'Very Mild Impairment'])
# Out:
# 40/40 [==============================] - 7s 137ms/step

# %%
print(cm)
print(cr)
# Out:
# [[ 64   2  23  90]
#  [  2   1   0   9]
#  [ 30   0 444 166]
#  [ 26   0 153 269]]
#                       precision    recall  f1-score   support
#
#      Mild Impairment       0.52      0.36      0.43       179
#  Moderate Impairment       0.33      0.08      0.13        12
#        No Impairment       0.72      0.69      0.70       640
# Very Mild Impairment       0.50      0.60      0.55       448
#
#             accuracy                           0.61      1279
#            macro avg       0.52      0.43      0.45      1279
#         weighted avg       0.61      0.61      0.61      1279

# %%
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_pred,test_set.classes)))
print('Cohen Kappa Score: {:.2f}'.format(cohen_kappa_score(y_pred,test_set.classes)))
print('Recall: {:.2f}'.format(recall_score(test_set.classes, y_pred, average='micro')))
print('F1-score: {:.2f}'.format(f1_score(test_set.classes, y_pred, average='micro')))
print('Precision: {:.2f}'.format(precision_score(test_set.classes, y_pred, average='macro')))
# Out:
# Accuracy: 0.61
#
# Cohen Kappa Score: 0.34
# Recall: 0.61
# F1-score: 0.61
# Precision: 0.52

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Mild Impairment', 'Moderate Impairment', 'No Impairment', 'Very Mild Impairment'], yticklabels=['Mild Impairment', 'Moderate Impairment', 'No Impairment', 'Very Mild Impairment'], cbar=False)
plt.xticks(rotation=30)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
